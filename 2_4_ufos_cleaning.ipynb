# %%
import pandas as pd

# %%
ufos = pd.read_csv('scrubbed.csv', low_memory = False)

# %%
ufos.head()
# Out:
#            datetime                  city state country     shape  \
# 0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb    tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3  10/10/1956 21:00                  edna    tx      us    circle
# 4  10/10/1960 20:00               kaneohe    hi      us     light
#
#   duration (seconds) duration (hours/min)  \
# 0               2700           45 minutes
# 1               7200              1-2 hrs
# 2                 20           20 seconds
# 3                 20             1/2 hour
# 4                900           15 minutes
#
#                                             comments date posted    latitude  \
# 0  This event took place in early fall around 194...   4/27/2004  29.8830556
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005    29.38421
# ...

# %%
ufos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80332 entries, 0 to 80331
# Data columns (total 11 columns):
# datetime                80332 non-null object
# city                    80332 non-null object
# state                   74535 non-null object
# country                 70662 non-null object
# shape                   78400 non-null object
# duration (seconds)      80332 non-null object
# duration (hours/min)    80332 non-null object
# comments                80317 non-null object
# date posted             80332 non-null object
# latitude                80332 non-null object
# longitude               80332 non-null float64
# dtypes: float64(1), object(10)
# memory usage: 6.7+ MB

# %%
ufos.shape
# Out:
# (80332, 11)

# %%
ufos.columns
# Out:
# Index(['datetime', 'city', 'state', 'country', 'shape', 'duration (seconds)',
#        'duration (hours/min)', 'comments', 'date posted', 'latitude',
#        'longitude '],
#       dtype='object')

# %%
ufos.rename(columns = {'duration (seconds)': 'duration_seconds', 'duration (hours/min)': 'duration_hours_min', 'date posted': 'date_posted', 'longitude ': 'longitude'}, inplace = True)

# %%
ufos.columns
# Out:
# Index(['datetime', 'city', 'state', 'country', 'shape', 'duration_seconds',
#        'duration_hours_min', 'comments', 'date_posted', 'latitude',
#        'longitude'],
#       dtype='object')

# %%
ufos.dtypes
# Out:
# datetime               object
# city                   object
# state                  object
# country                object
# shape                  object
# duration_seconds       object
# duration_hours_min     object
# comments               object
# date_posted            object
# latitude               object
# longitude             float64
# dtype: object

# %%
ufos.head()
# Out:
#            datetime                  city state country     shape  \
# 0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb    tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3  10/10/1956 21:00                  edna    tx      us    circle
# 4  10/10/1960 20:00               kaneohe    hi      us     light
#
#   duration_seconds duration_hours_min  \
# 0             2700         45 minutes
# 1             7200            1-2 hrs
# 2               20         20 seconds
# 3               20           1/2 hour
# 4              900         15 minutes
#
#                                             comments date_posted    latitude  \
# 0  This event took place in early fall around 194...   4/27/2004  29.8830556
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005    29.38421
# 2  Green/Orange circular disc over Chester&#44 En...   1/21/2008        53.2
# ...

# %%
set(ufos['datetime'])
# Out:
# {'11/9/1999 22:49',
#  '8/26/2011 00:00',
#  '4/3/2005 13:50',
#  '10/15/1975 03:00',
#  '3/7/2011 18:50',
#  '12/15/2007 19:10',
#  '1/15/2014 19:45',
#  '4/16/2005 17:00',
#  '5/29/2012 23:00',
#  '12/22/1965 09:00',
#  '11/12/2013 19:00',
#  '12/21/1998 02:10',
#  '4/9/2005 22:50',
#  '3/21/2014 15:20',
#  '11/17/2008 18:00',
#  '9/18/2005 23:30',
#  '8/2/2008 02:00',
#  '12/6/2008 23:32',
#  '3/20/2009 18:59',
#  '3/29/2013 21:00',
#  '4/5/2008 23:45',
#  '1/12/2012 22:00',
#  '5/26/2008 22:00',
#  '10/24/2008 24:00',
#  '3/21/2013 18:00',
#  '4/18/2012 12:41',
#  '5/27/2012 21:24',
#  '6/6/1957 22:00',
#  '7/10/2010 23:20',
#  '7/15/2005 17:00',
#  '9/10/1995 09:30',
#  '3/13/2001 19:30',
#  '10/29/2000 18:45',
#  '12/8/2011 01:13',
#  '5/4/2010 21:30',
#  '3/1/2007 19:10',
#  '12/31/2010 16:26',
#  '10/6/1999 22:46',
#  '11/18/2000 19:30',
#  '7/1/1985 20:30',
#  '7/19/2002 19:50',
#  '10/15/2007 22:30',
#  '11/4/2009 18:00',
#  '12/16/2009 06:30',
#  '7/12/1997 02:45',
# ...

# %%
ufos.astype({'datetime': 'datetime64[ns]', 'date_posted':'datetime64[ns]', 'duration_seconds': int, 'latitude': float})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/pandas/core/tools/datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     376             try:
# --> 377                 values, tz = conversion.datetime_to_datetime64(arg)
#     378                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-b24600bb4c5c> in <module>
# ----> 1 ufos.astype({'datetime': 'datetime64[ns]', 'date_posted':'datetime64[ns]', 'duration_seconds': int, 'latitude': float})
#
# ...

# %%
ufos.astype({ 'duration_seconds': float})

# %%
ufos.astype({ 'latitude': float})

# %%
ufos.astype({'date_posted' :'datetime64[ns]'}, inplace = True)

# %%
ufos['date_posted'] = ufos['date_posted'].astype('datetime64[ns]')

# %% [markdown]
# # Latitude

# %%
ufos.astype({ 'latitude': float})

# %%
ufos[ufos['latitude'] == '33.200088']

# %%
ufos[ufos['latitude'] == '33q.200088']['latitude'] = '33.200088'
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
ufos.loc[43782, 'latitude'] = '33.200088'

# %%
ufos.astype({ 'latitude': float}, inplace = True)
# Out:
#                datetime                                   city state country  \
# 0      10/10/1949 20:30                             san marcos    tx      us
# 1      10/10/1949 21:00                           lackland afb    tx     NaN
# 2      10/10/1955 17:00                   chester (uk/england)   NaN      gb
# 3      10/10/1956 21:00                                   edna    tx      us
# 4      10/10/1960 20:00                                kaneohe    hi      us
# 5      10/10/1961 19:00                                bristol    tn      us
# 6      10/10/1965 21:00                     penarth (uk/wales)   NaN      gb
# 7      10/10/1965 23:45                                norwalk    ct      us
# 8      10/10/1966 20:00                              pell city    al      us
# 9      10/10/1966 21:00                               live oak    fl      us
# 10     10/10/1968 13:00                              hawthorne    ca      us
# ...

# %%
ufos['latitude'] = ufos['latitude'].replace('33q.200088', '33.200088')

# %%
ufos['latitude'] = ufos['latitude'] .astype( 'float64')

# %%
ufos.dtypes
# Out:
# datetime               object
# city                   object
# state                  object
# country                object
# shape                  object
# duration_seconds       object
# duration_hours_min     object
# comments               object
# date_posted            object
# latitude              float64
# longitude             float64
# dtype: object

# %% [markdown]
# # Datetime

# %%
ufos.astype({'datetime': 'datetime64[ns]'})
# Out:
#                  datetime                                   city state  \
# 0     1949-10-10 20:30:00                             san marcos    tx
# 1     1949-10-10 21:00:00                           lackland afb    tx
# 2     1955-10-10 17:00:00                   chester (uk/england)   NaN
# 3     1956-10-10 21:00:00                                   edna    tx
# 4     1960-10-10 20:00:00                                kaneohe    hi
# 5     1961-10-10 19:00:00                                bristol    tn
# 6     1965-10-10 21:00:00                     penarth (uk/wales)   NaN
# 7     1965-10-10 23:45:00                                norwalk    ct
# 8     1966-10-10 20:00:00                              pell city    al
# 9     1966-10-10 21:00:00                               live oak    fl
# 10    1968-10-10 13:00:00                              hawthorne    ca
# 11    1968-10-10 19:00:00                                brevard    nc
# ...

# %%
ufos.dtypes
# Out:
# datetime               object
# city                   object
# state                  object
# country                object
# shape                  object
# duration_seconds       object
# duration_hours_min     object
# comments               object
# date_posted            object
# latitude              float64
# longitude             float64
# dtype: object

# %%
ufos['24' in ufos['datetime']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-fce7cd8d5e3a> in <module>
# ----> 1 ufos['24' in ufos['datetime']]
#
# ...

# %%
ufos['date_24'] = ufos['datetime'].apply(lambda x: '24:' in x)

# %%
ufos[ufos['date_24'] == True ]
# Out:
# Empty DataFrame
# Columns: [datetime, city, state, country, shape, duration_seconds, duration_hours_min, comments, date_posted, latitude, longitude, date_24]
# Index: []

# %%
ufos['datetime'] = ufos['datetime'].replace('24:', '00:')

# %%
ufos.astype({'datetime': 'datetime64[ns]'}, inplace = True)
# Out:
#                  datetime                                   city state  \
# 0     1949-10-10 20:30:00                             san marcos    tx
# 1     1949-10-10 21:00:00                           lackland afb    tx
# 2     1955-10-10 17:00:00                   chester (uk/england)   NaN
# 3     1956-10-10 21:00:00                                   edna    tx
# 4     1960-10-10 20:00:00                                kaneohe    hi
# 5     1961-10-10 19:00:00                                bristol    tn
# 6     1965-10-10 21:00:00                     penarth (uk/wales)   NaN
# 7     1965-10-10 23:45:00                                norwalk    ct
# 8     1966-10-10 20:00:00                              pell city    al
# 9     1966-10-10 21:00:00                               live oak    fl
# 10    1968-10-10 13:00:00                              hawthorne    ca
# 11    1968-10-10 19:00:00                                brevard    nc
# ...

# %%
ufos['date_24'] = ufos['datetime'].apply(lambda x: '24:' in x)
ufos[ufos['date_24'] == True ]
# Out:
# Empty DataFrame
# Columns: [datetime, city, state, country, shape, duration_seconds, duration_hours_min, comments, date_posted, latitude, longitude, date_24]
# Index: []

# %%
ufos['datetime'] = ufos['datetime'].replace('24:', '00:')

# %%
ufos[ufos['date_24'] == True ]
# Out:
# Empty DataFrame
# Columns: [datetime, city, state, country, shape, duration_seconds, duration_hours_min, comments, date_posted, latitude, longitude, date_24]
# Index: []

# %%
ufos['datetime'] = ufos['datetime'].apply(lambda x: x.replace('24:', '00:'))

# %%
ufos['datetime'] = ufos['datetime'].astype('datetime64[ns]')

# %% [markdown]
# # Duration_seconds

# %%
ufos.astype({'duration_seconds': float})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-9ef586496a34> in <module>
# ----> 1 ufos.astype({'duration_seconds': float})
#
# /anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4988             for col_name, col in self.iteritems():
#    4989                 if col_name in dtype:
# -> 4990                     results.append(col.astype(dtype[col_name], copy=copy))
#    4991                 else:
# ...

# %%
ufos['duration_seconds'] = ufos['duration_seconds'].apply(lambda x: x.replace('`', ''))

# %%
ufos['duration_seconds'] = ufos['duration_seconds'].astype('float64')

# %%
ufos.dtypes
# Out:
# datetime              datetime64[ns]
# city                          object
# state                         object
# country                       object
# shape                         object
# duration_seconds             float64
# duration_hours_min            object
# comments                      object
# date_posted           datetime64[ns]
# latitude                     float64
# longitude                    float64
# date_24                         bool
# dtype: object

# %%
ufos.head()
# Out:
#              datetime                  city state country     shape  \
# 0 1949-10-10 20:30:00            san marcos    tx      us  cylinder
# 1 1949-10-10 21:00:00          lackland afb    tx     NaN     light
# 2 1955-10-10 17:00:00  chester (uk/england)   NaN      gb    circle
# 3 1956-10-10 21:00:00                  edna    tx      us    circle
# 4 1960-10-10 20:00:00               kaneohe    hi      us     light
#
#    duration_seconds duration_hours_min  \
# 0            2700.0         45 minutes
# 1            7200.0            1-2 hrs
# 2              20.0         20 seconds
# 3              20.0           1/2 hour
# 4             900.0         15 minutes
#
#                                             comments date_posted   latitude  \
# 0  This event took place in early fall around 194...   4/27/2004  29.883056
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005  29.384210
# 2  Green/Orange circular disc over Chester&#44 En...   1/21/2008  53.200000
# ...

# %% [markdown]
# # NaN values

# %%
ufos.isnull()
# Out:
#        datetime   city  state  country  shape  duration_seconds  \
# 0         False  False  False    False  False             False
# 1         False  False  False     True  False             False
# 2         False  False   True    False  False             False
# 3         False  False  False    False  False             False
# 4         False  False  False    False  False             False
# 5         False  False  False    False  False             False
# 6         False  False   True    False  False             False
# 7         False  False  False    False  False             False
# 8         False  False  False    False  False             False
# 9         False  False  False    False  False             False
# 10        False  False  False    False  False             False
# 11        False  False  False    False  False             False
# 12        False  False  False    False  False             False
# 13        False  False  False    False  False             False
# ...

# %%
ufos.isnull().sum()
# Out:
# datetime                 0
# city                     0
# state                 5797
# country               9670
# shape                 1932
# duration_seconds         0
# duration_hours_min       0
# comments                15
# date_posted              0
# latitude                 0
# longitude                0
# date_24                  0
# dtype: int64

# %%
ufos['comments'] = ufos['comments'].fillna('No comments')

# %%
ufos.isnull().sum()
# Out:
# datetime                 0
# city                     0
# state                 5797
# country               9670
# shape                 1932
# duration_seconds         0
# duration_hours_min       0
# comments                 0
# date_posted              0
# latitude                 0
# longitude                0
# date_24                  0
# dtype: int64
